# %%
import liana as li
import scanpy as sc
from anndata import AnnData
import pandas as pd
from liana.mt import rank_aggregate
from liana.method import singlecellsignalr, connectome, cellphonedb, natmi, logfc, cellchat, geometric_mean
from pycirclize import Circos
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# loading original anndata
pvat_24weeks_control_male = sc.read_h5ad('../../exported_data/pvat_24weeks_control_male.h5ad')
pvat_24weeks_control_male
# Out:
# AnnData object with n_obs × n_vars = 11457 × 20743
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'n_genes', 'scDblFinder_score', 'scDblFinder_class', 'Sample', 'tissue', 'diet', 'time', 'sex', 'batch', 'sample_type', 'rat_id', 'weight_3W', 'weight_10W', 'weight_17W', 'weight_24W', 'MAP_7W', 'systolic_bp_7W', 'MAP_9W', 'systolic_bp_9W', 'MAP_16W', 'systolic_bp_16W', 'MAP_24W', 'systolic_bp_24W', 'doublet', 'celltype', 'celltype_broad'
#     var: 'gene_ids', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'cellchat_interaction_table_count', 'cellchat_res', 'cellchat_res_filtered', 'cellphonedb_interaction_table_count', 'cellphonedb_res', 'cellphonedb_res_filtered', 'nichenet_interaction_table_count', 'nichenet_lr_res', 'nichenet_res_filtered'
#     layers: 'counts', 'raw_counts', 'soupX_counts'

# %%
pvat_24weeks_control_male.obs['celltype_broad'].unique().tolist()
# Out:
# ['Endothelial_Cells',
#  'Adipocytes',
#  'Pericytes',
#  'Fibroblasts',
#  'Immune_Cells',
#  'SMCs',
#  'Mesothelial_Cells',
#  'Neuronal_Cells']

# %%
# List available methods in lliana framework
li.mt.show_methods()
# Out:
#          Method Name Magnitude Score Specificity Score  \
# 0        CellPhoneDB        lr_means   cellphone_pvals
# 0         Connectome       expr_prod     scaled_weight
# 0             log2FC            None          lr_logfc
# 0              NATMI       expr_prod       spec_weight
# 0  SingleCellSignalR         lrscore              None
# 0           CellChat        lr_probs    cellchat_pvals
# 0     Rank_Aggregate  magnitude_rank  specificity_rank
# 0     Geometric Mean       lr_gmeans       gmean_pvals
#
#                                            Reference
# 0  Efremova, M., Vento-Tormo, M., Teichmann, S.A....
# 0  Raredon, M.S.B., Yang, J., Garritano, J., Wang...
# 0  Dimitrov, D., Türei, D., Garrido-Rodriguez, M....
# 0  Hou, R., Denisenko, E., Ong, H.T., Ramilowski,...
# 0  Cabello-Aguilar, S., Alame, M., Kon-Sun-Tack, ...
# 0  Jin, S., Guerrero-Juarez, C.F., Zhang, L., Cha...
# 0  Dimitrov, D., Türei, D., Garrido-Rodriguez, M....
# 0  CellPhoneDBv2's permutation approach applied t...

# %%
pvat_24weeks_control_male.raw = pvat_24weeks_control_male
pvat_24weeks_control_male.raw.X
# Out:
# <11457x20743 sparse matrix of type '<class 'numpy.float64'>'
# 	with 20434105 stored elements in Compressed Sparse Row format>

# %%
# Run CellPhoneDB analysis on PVAT data
cellphonedb(pvat_24weeks_control_male, groupby='celltype_broad', expr_prop=0.1, resource_name='mouseconsensus', verbose=True, key_added='cellphonedb_res')
# Out:
# Using `.raw`!
# /Users/pandavis/miniconda3/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# 1109 features of mat are empty, they will be removed.
# Make sure that normalized counts are passed!
# /Users/pandavis/miniconda3/lib/python3.11/site-packages/liana/method/_pipe_utils/_pre.py:148: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# ['Cyp2c6_v1-ps2'] contain `_`. Consider replacing those!
# Using resource `mouseconsensus`.
# 0.19 of entities in the resource are missing from the data.
# Generating ligand-receptor stats for 11457 samples and 19634 features
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 184.05it/s]

# %%
ligand_receptor_pvat = pvat_24weeks_control_male.uns['cellphonedb_res']
ligand_receptor_pvat.head()
# Out:
#       ligand ligand_complex  ligand_means  ligand_props receptor  \
# 2561   Slit3          Slit3     43.903225      1.000000    Robo4
# 12954  Slit3          Slit3     43.903225      1.000000    Robo2
# 12363  Ncam1          Ncam1      3.684210      0.842105  Cacna1c
# 12080  Ncam1          Ncam1      0.208000      0.136000  Cacna1c
# 11581  Lama2          Lama2     10.536393      0.968182    Itga1
#
#       receptor_complex  receptor_means  receptor_props             source  \
# 2561             Robo4        0.433526        0.308836               SMCs
# 12954            Robo2        0.290323        0.193548               SMCs
# 12363          Cacna1c       19.354837        1.000000     Neuronal_Cells
# 12080          Cacna1c       19.354837        1.000000  Mesothelial_Cells
# 11581            Itga1        5.516129        0.967742        Fibroblasts
#
#                   target   lr_means  cellphone_pvals
# 2561   Endothelial_Cells  22.168375              0.0
# 12954               SMCs  22.096773              0.0
# 12363               SMCs  11.519524              0.0
# 12080               SMCs   9.781419              0.0
# 11581               SMCs   8.026260              0.0

# %%
ligand_receptor_string = (ligand_receptor_pvat.loc[:,'ligand_complex'].str.contains('Col')) & (ligand_receptor_pvat.loc[:,'receptor_complex'].str.contains('Itg'))
cell_source_string = ligand_receptor_pvat.loc[:,'source'] == 'Fibroblasts'
cell_target_string = ligand_receptor_pvat.loc[:,'target'] == 'Adipocytes'
cell_pvals = ligand_receptor_pvat.loc[:,'cellphone_pvals'] <= 0.05

ligand_receptor_pvat[ligand_receptor_string & cell_source_string & cell_target_string & cell_pvals]
# Out:
#       ligand ligand_complex  ligand_means  ligand_props receptor  \
# 295   Col4a1         Col4a1      7.565171      0.786364    Itgb1
# 326   Col5a3         Col5a3      4.887888      0.842424    Itgb1
# 301   Col4a2         Col4a2      4.842431      0.771212    Itgb1
# 384   Col4a2         Col4a2      4.842431      0.771212    Itgb5
# 289   Col6a6         Col6a6      3.625755      0.689394    Itgb1
# 332   Col3a1         Col3a1      3.416664      0.757576    Itgb1
# 305   Col6a2         Col6a2      2.825755      0.800000    Itgb1
# 328   Col5a2         Col5a2      2.378786      0.727273    Itgb1
# 307   Col6a3         Col6a3      2.115150      0.693939    Itgb1
# 303   Col6a1         Col6a1      1.851514      0.663636    Itgb1
# 291   Col6a5         Col6a5      1.801514      0.404545    Itgb1
# 319  Col15a1        Col15a1      1.721211      0.584848    Itgb1
# 330   Col5a1         Col5a1      1.406059      0.645455    Itgb1
# 299   Col1a2         Col1a2      1.189393      0.524242    Itgb1
# 311   Col4a4         Col4a4      0.928787      0.480303    Itgb1
# 314   Col4a3         Col4a3      0.919696      0.410606    Itgb1
# 293   Col1a1         Col1a1      0.881818      0.415152    Itgb1
# 334  Col14a1        Col14a1      0.501515      0.175758    Itgb1
# 309   Col4a5         Col4a5      0.209091      0.131818    Itgb1
#
#     receptor_complex  receptor_means  receptor_props       source      target  \
# 295      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 326      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 301      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 384            Itgb5        0.408004        0.269600  Fibroblasts  Adipocytes
# 289      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 332      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 305      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 328      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 307      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 303      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 291      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 319      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 330      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 299      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 311      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 314      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 293      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 334      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
# 309      Itga1_Itgb1        0.733476        0.433067  Fibroblasts  Adipocytes
#
#      lr_means  cellphone_pvals
# 295  4.149323              0.0
# 326  2.810682              0.0
# 301  2.787954              0.0
# 384  2.625218              0.0
# 289  2.179615              0.0
# 332  2.075070              0.0
# 305  1.779616              0.0
# 328  1.556131              0.0
# 307  1.424313              0.0
# 303  1.292495              0.0
# 291  1.267495              0.0
# 319  1.227344              0.0
# 330  1.069768              0.0
# 299  0.961435              0.0
# 311  0.831132              0.0
# 314  0.826586              0.0
# 293  0.807647              0.0
# 334  0.617496              0.0
# 309  0.471284              0.0

# %%
ligand_receptor_pvat.to_csv("pvat_24weeks_control_male_cellphonedb.csv")
pvat_24weeks_control_male.write("../../exported_data/pvat_24weeks_control_male.h5ad")
