# %%
# 24 W Male 
import pandas as pd

# %%
# Good resource for TF - target genes: https://www.grnpedia.org/trrust/key_regulator/015fc0d93c.php

# %%
quadrant_0_male = pd.read_csv('../../data/taPVAT_Adipocytes_Brown_Male_MetaDEGs_Quadrant_0.csv')
quadrant_3_male = pd.read_csv('../../data/taPVAT_Adipocytes_Brown_Male_MetaDEGs_Quadrant_3.csv')

# %%
quadrant_0_list= list(quadrant_0_male['gene_id'])
quadrant_3_list = list(quadrant_3_male['gene_id'])

# %%
combined_list = set(quadrant_0_list + quadrant_3_list)

# %%
combined_list_capitalized = [gene.upper() for gene in combined_list]

# %%
# Remove genes starting with 'ENSRN' and print them
to_remove = [gene for gene in combined_list_capitalized if gene.startswith('ENSRN')]
to_remove2 = [gene for gene in combined_list_capitalized if gene.startswith('LOC')]
to_remove3 = [gene for gene in combined_list_capitalized if gene.startswith('AABR')]
for gene in to_remove:
    print(f'Removed gene: {gene}')
    combined_list_capitalized.remove(gene)
for gene in to_remove2:
    print(f'Removed gene: {gene}')
    combined_list_capitalized.remove(gene)
for gene in to_remove3:
    print(f'Removed gene: {gene}')
    combined_list_capitalized.remove(gene)
# Out:
# Removed gene: ENSRNOG00000062892
# Removed gene: ENSRNOG00000068992
# Removed gene: ENSRNOG00000068479
# Removed gene: ENSRNOG00000067157
# Removed gene: ENSRNOG00000067822
# Removed gene: ENSRNOG00000055485
# Removed gene: ENSRNOG00000068888
# Removed gene: ENSRNOG00000064128
# Removed gene: ENSRNOG00000069911
# Removed gene: ENSRNOG00000068898
# Removed gene: ENSRNOG00000064991
# Removed gene: ENSRNOG00000010657
# Removed gene: ENSRNOG00000064022
# Removed gene: ENSRNOG00000066594
# Removed gene: ENSRNOG00000069857
# Removed gene: ENSRNOG00000070543
# Removed gene: ENSRNOG00000038299
# Removed gene: ENSRNOG00000068850
# Removed gene: ENSRNOG00000069235
# Removed gene: ENSRNOG00000071112
# Removed gene: ENSRNOG00000064539
# Removed gene: ENSRNOG00000063799
# Removed gene: ENSRNOG00000065910
# Removed gene: ENSRNOG00000070490
# Removed gene: ENSRNOG00000068783
# Removed gene: ENSRNOG00000065279
# Removed gene: ENSRNOG00000068250
# Removed gene: ENSRNOG00000032195
# Removed gene: ENSRNOG00000070520
# Removed gene: ENSRNOG00000068345
# Removed gene: ENSRNOG00000065129
# Removed gene: ENSRNOG00000063228
# Removed gene: ENSRNOG00000063733
# Removed gene: ENSRNOG00000068353
# Removed gene: ENSRNOG00000070786
# Removed gene: ENSRNOG00000063680
# Removed gene: ENSRNOG00000065049
# Removed gene: ENSRNOG00000033449
# Removed gene: ENSRNOG00000063951
# Removed gene: ENSRNOG00000029004
# Removed gene: ENSRNOG00000071027
# Removed gene: ENSRNOG00000070314
# Removed gene: ENSRNOG00000069326
# Removed gene: ENSRNOG00000066171
# Removed gene: ENSRNOG00000065440
# Removed gene: ENSRNOG00000062486
# Removed gene: ENSRNOG00000064109
# Removed gene: ENSRNOG00000065873
# Removed gene: ENSRNOG00000069366
# Removed gene: ENSRNOG00000058912
# Removed gene: ENSRNOG00000068194
# Removed gene: ENSRNOG00000065404
# Removed gene: ENSRNOG00000069502
# Removed gene: ENSRNOG00000066500
# Removed gene: ENSRNOG00000069832
# Removed gene: ENSRNOG00000063619
# Removed gene: ENSRNOG00000071060
# Removed gene: ENSRNOG00000069347
# Removed gene: ENSRNOG00000065256
# Removed gene: ENSRNOG00000068825
# Removed gene: ENSRNOG00000062835
# Removed gene: ENSRNOG00000070065
# Removed gene: ENSRNOG00000029588
# Removed gene: ENSRNOG00000064081
# Removed gene: ENSRNOG00000066737
# Removed gene: ENSRNOG00000063969
# Removed gene: ENSRNOG00000067063
# Removed gene: ENSRNOG00000068893
# Removed gene: ENSRNOG00000067218
# Removed gene: ENSRNOG00000062547
# Removed gene: ENSRNOG00000070944
# Removed gene: ENSRNOG00000063779
# Removed gene: ENSRNOG00000068999
# Removed gene: ENSRNOG00000064487
# Removed gene: ENSRNOG00000066455
# Removed gene: LOC691519
# Removed gene: LOC100362172
# Removed gene: LOC108348070
# Removed gene: LOC102556463
# Removed gene: LOC690507
# Removed gene: LOC120099313
# Removed gene: LOC102549789
# Removed gene: LOC120095539
# Removed gene: LOC100361645
# Removed gene: LOC108348989
# Removed gene: LOC103691943
# Removed gene: LOC102552900
# Removed gene: LOC686087
# Removed gene: LOC108352413
# Removed gene: LOC102551133
# Removed gene: LOC120102487
# Removed gene: LOC120096194
# Removed gene: LOC681186
# Removed gene: LOC100363452
# Removed gene: LOC304239
# Removed gene: LOC691418
# Removed gene: LOC120099108
# Removed gene: LOC103691652
# Removed gene: AABR07060591.1
# Removed gene: AABR07049554.2
# Removed gene: AABR07054614.1
# Removed gene: AABR07062466.1
# Removed gene: AABR07054096.1
# Removed gene: AABR07012054.1
# Removed gene: AABR07025743.1

# %%
print(*combined_list_capitalized, sep="\n")
# Out:
# SH3GL2
# CHRM5
# ASIC2
# AC098622.1
# ARR3
# ADAM2
# NECAB1
# NEK6
# S100A1
# IGFBP5
# TERB1
# LMX1B
# NPR1
# CXCR6
# TEKTIP1
# AC133403.1
# URM1-1
# SYBU
# KCNG2
# ENO2
# IRGM
# ECT2L
# STOX2
# RGD1565989
# GC
# RIPOR2
# ADAMTSL4
# ACSL5
# RGD1560775
# GCNT7
# CITED2
# AGT
# SPOPFM2L1
# AFAP1L2
# CAR6
# CFAP54
# STON1
# HTR2B
# CTF2
# SLCO3A1
# GDAP1
# SEPTIN4
# TSGA10IP
# CNR1
# KLHL1
# PLEKHA2
# GM10135
# PAM
# PPP1R26
# AKR1C14
# VOM2R3
# SCUBE3
# GABRB3
# RNF182
# TMOD4
# GPR34
# FBXO5
# TWIST1
# PLPP3
# LRRC1
# SULF1
# C1H11ORF42
# SMPD3
# SLC3A1
# HBB
# GARIN2
# RGD1564696
# FUT10
# ANXA9
# NNAT
# ATP8B1
# RIPK3
# FLVCR2
# COL4A3
# TRPV4
# LAG3
# H2BC18
# AXDND1
# IGFBP7
# ZC3H12B
# EVI2B
# FSCN2
# GLS2
# FLRT1
# PACSIN3
# HYI
# CYP2J10
# KCNAB1
# ANKRD55
# PROS1
# RGD1359290
# SHROOM1
# ASPN
# ZFP296
# CBLB
# IGSF6
# RPH3AL
# IGDCC3
# CFH
# ADAM32
# CFAP119
# FASN
# IP6K3
# SMYD1
# ADAM11
# NTRK2
# SSX1
# MRPS17
# MYC
# FN1
# HOXB3
# WEE2
# SERPINE3
# GPNMB
# ROBO2
# GM15737
# GM17949
# SERPINE2
# NAV3
# STX3
# DNAH3
# LYZ2
# ITPRIPL2
# PLCE1
# NAV2
# CFD
# MST1R
# FMO2
# TBATA
# TRPV3
# TTC9
# SERPINC1
# TEX56P
# ALAS2
# BORCS6
# AK4
# RT1-T24-3
# RGD1564053
# EYA2
# SGCE
# CD80
# CCDC125
# COL10A1
# C5H9ORF152
# ANTXR1
# KCTD8
# AC133270.1
# FGF14
# SLC38A1
# OSMR
# TPPP2
# KDELR3
# TPRG1L
# FSD1L
# DDC
# ALPL
# EPHX1
# SSTR2
# SPATA9
# SLC22A1
# H4F3
# RASL12
# MAGIX
# MIER2
# HDX
# FAM81B
# SLC25A24
# FANCG
# KCTD4
# COX7A1
# PDE10A
# RBL1
# IRF6
# NTSR2
# LRFN1
# BOC
# SOCS2
# KCTD14
# NID1
# LRRC19
# MKRN2OS
# KLRG2
# ARAP2
# ELK3
# MARS2
# PKDREJ
# MYADM
# COL4A5
# OAZ3
# SNX10
# MOGAT2
# B3GALT2
# MPV17L
# NXN
# SHISA4
# AC1576
# SERPIND1
# GPRC5C
# CREB3L1
# EEIG1
# CCNA1
# PLEKHA6
# GASK1A
# KCND2
# EFHD1
# UBE2I
# LTBP1
# PDCL2
# TG
# C5AR2
# NHS
# PIF1
# GPR183
# CRYBA1
# KIRREL1
# AMPD1
# FZD8
# PEA15
# RAB31
# TFCP2L1
# DEUP1
# RHOH
# NCK2
# SLC16A12
# STRIP2
# LRRK2
# FGF16
# SH2D7
# OTUD7A
# MFSD6
# SLC16A13
# TMC4
# MZF1
# KCNK4
# EAF2
# ABCA1
# KLHL13
# RAPGEF5
# ACKR4
# SERINC4
# GABRG3
# GUSB
# FBXL13
# NT5E
# ARRB1

# %% [markdown]
# # I copied and pasted the list of genes into CHEA3 results and selected the Mean Rank tab. The Mean Rank selection criteria is the best performing criteria method by their Benchmarking predictions (Figure 1).
# ## https://maayanlab.cloud/chea3/#top

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#https://maayanlab.cloud/chea3/#top

# %%
df_Adipocytes_Brown = pd.read_csv('../../predictions/gene_scores/August18_10_18_gene_scores_Adipocytes_Brown_24W_M.csv')

# %%
df_Adipocytes_Brown
# Out:
#       Unnamed: 0            Gene     Score
# 0              0   6330411D24Rik -0.051604
# 1              1  AABR07000398.1  2.433098
# 2              2  AABR07001902.1 -0.017396
# 3              3  AABR07001942.1 -0.076840
# 4              4  AABR07002969.1 -0.291243
# ...          ...             ...       ...
# 4995        4995           Znrf1  0.760724
# 4996        4996             Zp2 -0.033844
# 4997        4997            Zpbp -0.005657
# 4998        4998          Zswim6  1.709437
# 4999        4999             Zyx  1.316703
#
# [5000 rows x 3 columns]

# %%
df_Adipocytes_Brown = df_Adipocytes_Brown[~df_Adipocytes_Brown['Gene'].str.startswith('Mt-')] # Removed mitochondrial genes
df_Adipocytes_Brown = df_Adipocytes_Brown[~df_Adipocytes_Brown['Gene'].str.startswith('AABR')]
df_Adipocytes_Brown = df_Adipocytes_Brown[~df_Adipocytes_Brown['Gene'].str.startswith('ENSRN')]

# %%
pval = 1.0

# %%
df_Adipocytes_Brown[df_Adipocytes_Brown['Gene'].str.startswith('Creb')]
# Out:
#      Unnamed: 0     Gene     Score
# 957         957  Creb3l1 -0.129875
# 958         958    Creb5  0.691750

# %%
# Add a new column with the absolute value of the score

df_Adipocytes_Brown['abs_score'] = df_Adipocytes_Brown['Score'].abs()


# Sort by absolute score

top_abs_Adipocytes_Brown = df_Adipocytes_Brown.sort_values('abs_score', ascending=False).head(50)

# %%
significant_quad_3 = quadrant_3_male[quadrant_3_male['pval']<pval]
significant_quad_3 = significant_quad_3[~significant_quad_3['gene_id'].str.startswith('Mt-')]
significant_quad_3 = significant_quad_3[~significant_quad_3['gene_id'].str.startswith('AABR')]
significant_quad_3 = significant_quad_3[~significant_quad_3['gene_id'].str.startswith('ENSRN')]

# %%
significant_quad_3
# Out:
#         gene_id   gene_id.1          celltype group   sub_id sub_id_2  \
# 0        Pde10a      Pde10a  Adipocytes_Brown  time  Control        M
# 1       Slc22a1     Slc22a1  Adipocytes_Brown  time  Control        M
# 2          Lyz2        Lyz2  Adipocytes_Brown  time  Control        M
# 3        Axdnd1      Axdnd1  Adipocytes_Brown  time  Control        M
# 4        Adam11      Adam11  Adipocytes_Brown  time  Control        M
# ..          ...         ...               ...   ...      ...      ...
# 125       Fbxo5       Fbxo5  Adipocytes_Brown  time  Control        M
# 126  RGD1564053  RGD1564053  Adipocytes_Brown  time  Control        M
# 127      Sh3gl2      Sh3gl2  Adipocytes_Brown  time  Control        M
# 128         Ddc         Ddc  Adipocytes_Brown  time  Control        M
# 130      Igdcc3      Igdcc3  Adipocytes_Brown  time  Control        M
#
#      log2FoldChange_Control  lfcSE_Control  log2FoldChange_HF  lfcSE_HF  \
# 0                 -4.944918       0.598814          -0.897037  0.708053
# 1                 -6.649179       2.450159          -2.996657  1.166783
# 2                 -4.349670       1.134708          -1.428476  0.746823
# 3                 -3.057039       0.755674          -0.652973  0.749907
# 4                 -2.617882       1.178299           0.251553  0.744475
# ..                      ...            ...                ...       ...
# 125               -1.554340       0.605849          -0.612459  0.471670
# 126               -1.185721       0.906912          -0.244486  0.822720
# 127               -1.307443       0.748306          -0.368156  0.682266
# 128               -0.958819       0.751318          -0.021425  0.635872
# 130               -1.303292       0.892448           0.370735  0.511894
#
#      log2FC_diff  se_delta         z      pval  padj_diff
# 0      -4.047881  0.927317 -4.365155  0.000013   0.150915
# 1      -3.652522  2.713791 -1.345912  0.178331   0.999957
# 2      -2.921194  1.358421 -2.150433  0.031521   0.999957
# 3      -2.404065  1.064614 -2.258157  0.023936   0.999957
# 4      -2.366328  1.393783 -1.697773  0.089551   0.999957
# ..           ...       ...       ...       ...        ...
# 125    -0.941881  0.767806 -1.226719  0.219928   0.999957
# 126    -0.941235  1.224483 -0.768680  0.442083   0.999957
# 127    -0.939287  1.012644 -0.927559  0.353636   0.999957
# 128    -0.937394  0.984282 -0.952363  0.340913   0.999957
# 130    -0.932557  1.028834 -0.906421  0.364713   0.999957
#
# [119 rows x 15 columns]

# %%
significant_quad_0 = quadrant_0_male[quadrant_0_male['pval']<pval]
significant_quad_0 = significant_quad_0[~significant_quad_0['gene_id'].str.startswith('Mt-')]
significant_quad_0 = significant_quad_0[~significant_quad_0['gene_id'].str.startswith('AABR')]
significant_quad_0 = significant_quad_0[~significant_quad_0['gene_id'].str.startswith('ENSRN')]

# %%
genes_that_went_up_in_HF = list(significant_quad_0['gene_id'])
genes_that_went_down_in_control = list(significant_quad_3['gene_id'])

# %%
df_Adipocytes_Brown['Score'].sort_values(ascending=False)
# Out:
# 336     8.774586
# 2941    7.341688
# 730     6.026893
# 2913    5.572265
# 1855    5.540569
#           ...
# 4050   -2.370237
# 3123   -2.823201
# 1841   -2.932928
# 111    -3.030543
# 103    -3.085831
# Name: Score, Length: 4545, dtype: float64

# %%
mask = (df_Adipocytes_Brown['Score'] > 0) & \
       (df_Adipocytes_Brown['Gene'].isin(genes_that_went_up_in_HF) |
        df_Adipocytes_Brown['Gene'].isin(genes_that_went_down_in_control))

df_filtered = df_Adipocytes_Brown[mask]

# %%
df_filtered.sort_values('Score',ascending=False)
# Out:
#       Unnamed: 0          Gene     Score  abs_score
# 4447        4447         Sulf1  4.808112   4.808112
# 389          389        Atp8b1  3.349606   3.349606
# 2255        2255        Igfbp7  2.956491   2.956491
# 4433        4433         Stox2  2.255811   2.255811
# 3813        3813       Rapgef5  2.041431   2.041431
# 3280        3280           Nxn  1.906709   1.906709
# 3385        3385           Pam  0.876833   0.876833
# 2834        2834         Ltbp1  0.760997   0.760997
# 3122        3122          Nav2  0.617118   0.617118
# 4775        4775         Trpv4  0.529858   0.529858
# 3930        3930        Rph3al  0.436924   0.436924
# 4100        4100       Septin4  0.436122   0.436122
# 194          194       Afap1l2  0.373540   0.373540
# 3432        3432        Pde10a  0.352002   0.352002
# 4276        4276       Slco3a1  0.328704   0.328704
# 3352        3352          Osmr  0.312100   0.312100
# 3134        3134          Nck2  0.304043   0.304043
# 4143        4143        Sh3gl2  0.262503   0.262503
# 1870        1870           Fn1  0.258421   0.258421
# 606          606       Ccdc125  0.250543   0.250543
# 3225        3225          Npr1  0.214014   0.214014
# 3890        3890          Rhoh  0.214009   0.214009
# 2389        2389        Kcnab1  0.213667   0.213667
# 255          255       Ankrd55  0.203928   0.203928
# 4198        4198      Slc16a13  0.200355   0.200355
# 4235        4235       Slc38a1  0.168830   0.168830
# 4441        4441          Stx3  0.113223   0.113223
# 2001        2001       Gm15737  0.104802   0.104802
# 4296        4296         Smpd3  0.100835   0.100835
# 2044        2044        Gpr183  0.081863   0.081863
# 3357        3357        Otud7a  0.074812   0.074812
# 2445        2445       Kirrel1  0.062424   0.062424
# 3899        3899         Ripk3  0.058564   0.058564
# 4436        4436        Strip2  0.053759   0.053759
# 2801        2801         Lrrc1  0.048402   0.048402
# 2693        2693     LOC686087  0.047500   0.047500
# 4114        4114      Serpine2  0.043675   0.043675
# 2246        2246        Igdcc3  0.038171   0.038171
# 63            63    AC098622.1  0.035868   0.035868
# 1627        1627         Efhd1  0.034000   0.034000
# 4314        4314         Snx10  0.032496   0.032496
# 2520        2520  LOC100363452  0.028895   0.028895
# 360          360         Asic2  0.025207   0.025207
# 3657        3657         Pros1  0.021244   0.021244
# 1803        1803         Fbxo5  0.019074   0.019074
# 3624        3624       Ppp1r26  0.015919   0.015919
# 915          915        Col4a5  0.015733   0.015733
# 1602        1602          Eaf2  0.014597   0.014597
# 4677        4677         Tmod4  0.012937   0.012937
# 3543        3543         Plce1  0.011217   0.011217
# 203          203           Agt  0.008049   0.008049
# 4213        4213      Slc25a24  0.006024   0.006024
# 136          136         Adam2  0.006008   0.006008
# 3921        3921         Robo2  0.001015   0.001015

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df_Adipocytes_Brown is already loaded and contains 'Gene' and 'Score' columns

# Top 20 most positive gene scores
top_pos = df_filtered.sort_values('Score', ascending=False).head(30)

plt.figure(dpi=150)
plt.bar(top_pos['Gene'], top_pos['Score'], color='darkgreen')
plt.xticks(rotation=90, fontsize=12)
plt.ylabel("scVIDR Gene Score", fontsize=14)
plt.title("Top 20 Positive Gene Scores", fontsize=16)
plt.tight_layout()
#plt.savefig("../figures/Top20PositiveGeneScores_24W_Brown_Adipocytes_Both.svg", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Genes that decreased in HF

# %%
quadrant_1_male = pd.read_csv('../../data/taPVAT_Adipocytes_Brown_Male_MetaDEGs_Quadrant_1.csv')
quadrant_2_male = pd.read_csv('../../data/taPVAT_Adipocytes_Brown_Male_MetaDEGs_Quadrant_2.csv')
significant_quad_1 = quadrant_1_male[quadrant_1_male['pval']<pval]
significant_quad_1 = significant_quad_1[~significant_quad_1['gene_id'].str.startswith('Mt-')]
significant_quad_1 = significant_quad_1[~significant_quad_1['gene_id'].str.startswith('AABR')]
significant_quad_1 = significant_quad_1[~significant_quad_1['gene_id'].str.startswith('ENSRN')]


significant_quad_2 = quadrant_2_male[quadrant_2_male['pval']<pval]
significant_quad_2 = significant_quad_2[~significant_quad_2['gene_id'].str.startswith('Mt-')]
significant_quad_2 = significant_quad_2[~significant_quad_2['gene_id'].str.startswith('AABR')]
significant_quad_2 = significant_quad_2[~significant_quad_2['gene_id'].str.startswith('ENSRN')]

genes_that_went_up_in_control = list(significant_quad_1['gene_id'])
genes_that_went_down_in_hf = list(significant_quad_2['gene_id'])


mask2 = (df_Adipocytes_Brown['Score'] > 0) & \
       (df_Adipocytes_Brown['Gene'].isin(genes_that_went_up_in_control) |
        df_Adipocytes_Brown['Gene'].isin(genes_that_went_down_in_hf))

df_filtered2 = df_Adipocytes_Brown[mask2]

# %%
df_filtered2
# Out:
#       Unnamed: 0      Gene     Score  abs_score
# 78            78     Abca8  0.042388   0.042388
# 224          224      Akt3  1.646308   1.646308
# 343          343    Arpc1b  0.778021   0.778021
# 356          356      Asb2  0.054967   0.054967
# 370          370      Atf3  0.078704   0.078704
# 412          412  Baiap2l1  0.093600   0.093600
# 478          478      Btg2  0.074889   0.074889
# 535          535  Cacna2d3  0.067218   0.067218
# 624          624   Ccdc85a  0.572056   0.572056
# 798          798    Chaf1a  0.050878   0.050878
# 968          968    Crybg1  0.008718   0.008718
# 1061        1061     Dach1  2.465436   2.465436
# 1132        1132       Dmd  0.769446   0.769446
# 1134        1134     Dmrt2  0.008129   0.008129
# 1704        1704    Errfi1  0.379119   0.379119
# 1711        1711      Etl4  1.623306   1.623306
# 1852        1852     Fkbp5  0.110406   0.110406
# 1942        1942     Gata6  0.138251   0.138251
# 2205        2205  Hsp90aa1  0.231598   0.231598
# 2414        2414     Kcnn3  0.314019   0.314019
# 2431        2431     Kif11  0.009456   0.009456
# 2779        2779      Lnx1  0.732210   0.732210
# 2829        2829     Lsamp  0.188236   0.188236
# 2873        2873      Maff  0.056254   0.056254
# 2908        2908     Mark1  0.236959   0.236959
# 2944        2944     Mef2c  1.723809   1.723809
# 2987        2987     Mki67  0.042524   0.042524
# 3089        3089     Myo1e  4.352410   4.352410
# 3136        3136    Nckap5  0.109007   0.109007
# 3212        3212    Notch1  0.611496   0.611496
# 3232        3232     Nr4a1  0.036703   0.036703
# 3233        3233     Nr4a3  0.690039   0.690039
# 3349        3349    Osbpl3  0.165081   0.165081
# 3367        3367     P2ry2  0.231281   0.231281
# 3464        3464     Pear1  0.386326   0.386326
# 3634        3634      Prg4  0.005025   0.005025
# 3822        3822  Rasgef1b  0.014487   0.014487
# 3826        3826   Rasgrp2  0.200187   0.200187
# 3838        3838    Rbfox1  0.040925   0.040925
# 3886        3886    Rhbdl3  0.001207   0.001207
# 3898        3898      Rin3  0.941813   0.941813
# 4145        4145  Sh3pxd2b  0.017085   0.017085
# 4163        4163     Shtn1  0.021945   0.021945
# 4393        4393   St6gal1  1.658698   1.658698
# 4583        4583     Thsd4  5.024427   5.024427
# 4729        4729      Tpm4  0.787958   0.787958
# 4738        4738     Traf5  0.127423   0.127423

# %%
#Top 20 most negative gene scores

top_neg = df_filtered2.sort_values('Score', ascending=True).head(30)

plt.figure(dpi=150) 
plt.bar(top_neg['Gene'], top_neg['Score'], color='darkred') 
plt.xticks(rotation=90, fontsize=12) 
plt.ylabel("scVIDR Gene Score", fontsize=14) 
plt.title("Top 20 Negative Gene Scores", fontsize=16)

plt.tight_layout() #plt.savefig("../figures/Top20NegativeGeneScores_24W_Brown_Adipocytes_Both.svg", bbox_inches="tight") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the data


# Sort by absolute value of score
df_Adipocytes_Brown['abs_score'] = df_Adipocytes_Brown['Score'].abs()
top_genes_df = df_Adipocytes_Brown.sort_values('abs_score', ascending=False).head(20)

# Plot
plt.figure(dpi=300)
plt.bar(top_genes_df['Gene'], top_genes_df['Score'])
plt.xticks(rotation=90, fontsize=12)
plt.ylabel(r"scVIDR Gene Score", fontsize=18)
plt.tight_layout()
#plt.savefig("../figures/4A.svg", bbox_inches="tight")
plt.show()

# %%
import gseapy as gp
import pandas as pd


# Rank by absolute score
df_Adipocytes_Brown['abs_score'] = df_Adipocytes_Brown['Score'].abs()
top_genes = df_Adipocytes_Brown.sort_values('abs_score', ascending=False).head(100)

# Extract gene list
glist = top_genes['Gene'].tolist()

glist_top_increase = df_Adipocytes_Brown.sort_values('Score', ascending=False).head(100)
glist_top_increase = glist_top_increase['Gene'].tolist()
# Enrichment analysis
enr = gp.enrichr(
    gene_list=glist_top_increase,
    gene_sets= ["GO_Biological_Process_2023"], #["WikiPathways_2024_Mouse"],
    organism='Mouse',
    #description='adipocytes_brown_top100',
    #outdir='results/enrichr_adipocytes_brown',
    cutoff=0.5  # relaxed cutoff
)

gp.plot.barplot(enr.results,title='Enrichr Analysis of Gene Scores \n for Genes that Increase Along Perturbation Axis',fs = 8, top_term = 20)
#plt.savefig("../figures/4B.svg", bbox_inches = "tight")
# enr.results.head(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import gseapy as gp
#       2 import pandas as pd
#       5 # Rank by absolute score
#
# ModuleNotFoundError: No module named 'gseapy'

# %%
import gseapy as gp
import pandas as pd

# Load gene scores
df_Adipocytes_Brown = pd.read_csv('../predictions/gene_scores/gene_scores_Adipocytes_Brown_8W.csv')

# Rank by absolute score
df_Adipocytes_Brown['abs_score'] = df_Adipocytes_Brown['Score'].abs()

glist_top_decrease = df_Adipocytes_Brown.sort_values('Score', ascending=True).head(100)
glist_top_decrease = glist_top_decrease['Gene'].tolist()

print(glist_top_decrease)
# Enrichment analysis
enr = gp.enrichr(
    gene_list=glist_top_decrease,
    gene_sets=["GO_Biological_Process_2023"], #["GO_Biological_Process_2023"],
    organism='Mouse',
    #description='adipocytes_brown_top100',
    #outdir='results/enrichr_adipocytes_brown',
    cutoff=0.5  # relaxed cutoff
)
enr.results.head(10)
gp.plot.barplot(enr.results,title='Enrichr Analysis of Gene Scores \n for Genes that Decrease Along Perturbation Axis',fs = 8, top_term = 20)
#plt.savefig("../figures/4B.svg", bbox_inches = "tight")

# %%
gp.plot.barplot(enr.results,title='Enrichr Analysis of Gene Scores \n for Bottom ',fs = 8, top_term = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 gp.plot.barplot(enr.results,title='Enrichr Analysis of Gene Scores \n for Bottom ',fs = 8, top_term = 20)
#
# NameError: name 'gp' is not defined

# %% [markdown]
# ![image.png](attachment:26a9f366-defe-45a2-b702-57b93272006c.png)

# %%
# 1	NR4A1	BABAM2	Repression	22159226
# 2	NR4A1	CCNA2	Repression	12842839
# 3	NR4A1	CDKN1B	Activation	12842839
# 4	NR4A1	CYP11A1	Unknown	20083153
# 5	NR4A1	CYP17A1	Unknown	20083153
# 6	NR4A1	E2F1	Activation	12947120
# 7	NR4A1	FASLG	Unknown	14563113
# 8	NR4A1	HSD3B2	Activation	15666793
# 9	NR4A1	HSD3B2	Unknown	15208301; 20083153; 23874725
# 10	NR4A1	MDM2	Repression	17139261
# 11	NR4A1	MMP2	Activation	22551568
# 12	NR4A1	RNF7	Repression	22159226
# 13	NR4A1	SERPINE1	Unknown	12506026
# 14	NR4A1	STAR	Unknown	20083153
# 15	NR4A1	TIMP2	Activation	22551568
# 16	NR4A1	TNF	Repression	19213954




### Regulators of NR4A1:
# TFs that regulate NR4A1  
# #	TF	Target	Mode of Regulation	References
# (PMID)
# 1	HDAC7	NR4A1	Unknown	15623513
# 2	HIF1A	NR4A1	Activation	14729605
# 3	MEF2C	NR4A1	Repression	18079734
# 4	PML	NR4A1	Repression	12032831
# 5	SP1	NR4A1	Unknown	8961265

# %% [markdown]
# ![image.png](attachment:34b1e052-46ce-4990-9610-d04c89c30b70.png)

# %%
glist_top_increase
